# %%
! git clone https://github.com/ajitharunai/Facial-Emotion-Recognition-with-OpenCV-and-Deepface/
# Out:
# Cloning into 'Facial-Emotion-Recognition-with-OpenCV-and-Deepface'...

# %%
# cd Facial-Emotion-Recognition-using-OpenCV-and-Deepface
! cd Facial-Emotion-Recognition-with-OpenCV-and-Deepface

# %%
# ! pip install -r requirements.txt
! pip install -r Facial-Emotion-Recognition-with-OpenCV-and-Deepface/requirements.txt
# Out:
# ...
#   Obtaining dependency information for deepface from https://files.pythonhosted.org/packages/ef/f1/de0fd235d6d927156d12b99e60460c87f17979df51f2bd2b88aded38836b/deepface-0.0.89-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for gdown>=3.10.1 from https://files.pythonhosted.org/packages/cb/56/f4845ed78723a4eb8eb22bcfcb46e1157a462c78c0a5ed318c68c98f9a79/gdown-5.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for mtcnn>=0.1.0 from https://files.pythonhosted.org/packages/09/d1/2a4269e387edb97484157b872fa8a1953b53dcafbe4842a1967f549ac5ea/mtcnn-0.1.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for retina-face>=0.0.1 from https://files.pythonhosted.org/packages/77/36/155fe445891fa32f003b2a7937e8ded07d34c5f8811732e1a24f5eb873ca/retina_face-0.0.15-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/88.4 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.4 kB ? eta -:--:--
# ...

# %%
! pip install deepface
! pip install opencv-python

# %% [markdown]
# ## Emotion Detection

# %%
import cv2
from deepface import DeepFace

# Load the pre-trained emotion detection model
model = DeepFace.build_model("Emotion")

# Define emotion labels
emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'Facial-Emotion-Recognition-with-OpenCV-and-Deepface\haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        image = cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)

        try:
            analyze = DeepFace.analyze(img_path=image , actions=['emotion'])
            cv2.putText(image, analyze[0]['dominant_emotion'], (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (224, 77, 176), 2)
            print(analyze[0]['dominant_emotion'])
        except:
            print('no face')
        
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# neutral
# neutral
# neutral
# sad
# neutral
# neutral
# neutral
# neutral
# neutral
# happy
# happy
# happy
# happy
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# angry
# angry
# fear
# angry
# angry
# angry
# angry
# angry
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# happy
# happy
# neutral
# happy
# happy
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# neutral
# happy
# happy
# neutral
# neutral
# neutral
# neutral
# neutral
# ...
